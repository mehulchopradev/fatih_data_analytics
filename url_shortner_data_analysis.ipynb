# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import json

# %%
filepath = '/Users/mehul.chopra/Downloads/data-analysis-data/url-shortner/usagov_bitly_data2012-03-16-1331923249.txt'

# %%
file = open(filepath)
lines = [json.loads(line) for line in file]

# %%
lines
# Out:
# [{'a': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.78 Safari/535.11',
#   'c': 'US',
#   'nk': 1,
#   'tz': 'America/New_York',
#   'gr': 'MA',
#   'g': 'A6qOVH',
#   'h': 'wfLQtf',
#   'l': 'orofrog',
#   'al': 'en-US,en;q=0.8',
#   'hh': '1.usa.gov',
#   'r': 'http://www.facebook.com/l/7AQEFzjSi/1.usa.gov/wfLQtf',
#   'u': 'http://www.ncbi.nlm.nih.gov/pubmed/22415991',
#   't': 1331923247,
#   'hc': 1331822918,
#   'cy': 'Danvers',
#   'll': [42.576698, -70.954903]},
#  {'a': 'GoogleMaps/RochesterNY',
#   'c': 'US',
#   'nk': 0,
#   'tz': 'America/Denver',
#   'gr': 'UT',
#   'g': 'mwszkS',
#   'h': 'mwszkS',
#   'l': 'bitly',
#   'hh': 'j.mp',
#   'r': 'http://www.AwareMap.com/',
#   'u': 'http://www.monroecounty.gov/etc/911/rss.php',
#   't': 1331923249,
#   'hc': 1308262393,
#   'cy': 'Provo',
#   'll': [40.218102, -111.613297]},
# ...

# %%
d1 = DataFrame(lines)

# %%
d1
# Out:
#        _heartbeat_                        ...                                                                          u
# 0              NaN                        ...                                http://www.ncbi.nlm.nih.gov/pubmed/22415991
# 1              NaN                        ...                                http://www.monroecounty.gov/etc/911/rss.php
# 2              NaN                        ...                          http://boxer.senate.gov/en/press/releases/0316...
# 3              NaN                        ...                                    http://apod.nasa.gov/apod/ap120312.html
# 4              NaN                        ...                          http://www.shrewsbury-ma.gov/egov/gallery/1341...
# 5              NaN                        ...                          http://www.shrewsbury-ma.gov/egov/gallery/1341...
# 6              NaN                        ...                          http://www.nasa.gov/mission_pages/nustar/main/...
# ...

# %%
d2 = d1['tz'].fillna('Missing')
d2[d2 == ''] = 'Missing'
d3 = d2.value_counts()
d4 = d3.head(10)
d4
# Out:
# America/New_York       1251
# Missing                 641
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
# Europe/London            74
# Asia/Tokyo               37
# Pacific/Honolulu         36
# Europe/Madrid            35
# America/Sao_Paulo        33
# Name: tz, dtype: int64

# %%
d4.plot(kind='barh')
plt.show()

# %%
s1 = d1['a'].dropna()
d5 = d1.loc[s1.index]
d5['os'] = np.where(d5['a'].str.contains('Windows'), 'Windows', 'Non Windows')
d6 = d5[['os', 'tz']]
s2 = d6['tz']
s3 = s2.fillna('Missing')
s3[s3 == ''] = 'Missing'
del d6['tz']
d6['tz'] = s3
d7 = d6.groupby(['tz', 'os']).size().unstack().fillna(0)
d8 = d7.loc[d4.index]
d8
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# os                   Non Windows  Windows
# America/New_York           339.0    912.0
# Missing                    245.0    276.0
# America/Chicago            115.0    285.0
# America/Los_Angeles        130.0    252.0
# America/Denver             132.0     59.0
# Europe/London               43.0     31.0
# Asia/Tokyo                   2.0     35.0
# Pacific/Honolulu             0.0     36.0
# Europe/Madrid               16.0     19.0
# America/Sao_Paulo           13.0     20.0

# %%
d8.plot(kind='barh', stacked=True)
plt.show()
